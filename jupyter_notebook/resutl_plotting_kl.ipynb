]

NAE2GT_robustness_075 =[
  0.185000002,
  0.173999995,
  0.189999998,
  0.169,
  0.210999995,
  0.234999999,
  0.239999995,
  0.225999996,
  0.238000005,
  0.248999998,
  0.217999995,
  0.256000012,
  0.25,
  0.230000004,
  0.234999999,
  0.215000004,
  0.238999993,
  0.259000003,
  0.261000007,
  0.241999999,
  0.259000003,
  0.268000007,
  0.261000007,
  0.254000008,
  0.261000007,
  0.263000011,
  0.294999987,
  0.279000014,
  0.275999993,
  0.273000002,
]

NAE2GT_clean_05 =[
  0.284999996,
  0.301999986,
  0.317999989,
  0.345999986,
  0.405999988,
  0.433999985,
  0.419,
  0.441000015,
  0.5,
  0.49000001,
  0.414000005,
  0.50999999,
  0.470999986,
  0.518999994,
  0.488000005,
  0.540000021,
  0.513999999,
  0.556999981,
  0.42899999,
  0.545000017,
  0.535000026,
  0.51700002,
  0.560000002,
  0.550999999,
  0.563000023,
  0.58099997,
  0.564999998,
  0.59799999,
  0.643999994,
  0.666000009,

]

NAE2GT_robustness_05 =[
  0.186000004,
  0.174999997,
  0.174999997,
  0.171000004,
  0.208000004,
  0.239999995,
  0.248999998,
  0.224999994,
  0.221000001,
  0.261000007,
  0.202999994,
  0.196999997,
  0.236000001,
  0.236000001,
  0.202999994,
  0.002,
  0.004,
  0.006,
  0.214000002,
  0.228,
  0.254999995,
  0.264999986,
  0.256000012,
  0.25,
  0.261999995,
  0.273000002,
  0.279000014,
  0.277999997,
  0.216999993,
  0.001,

]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator

# my_font = {'family' : '',
# 'weight' : 'normal',
# 'size'   : 18,
# }

fig, ax = plt.subplots()

l1=plt.plot(KL_reuslt_clean ,'r--',label='LogitAlign')
l1=plt.plot(KL_reuslt_robust ,'r',label='LogitAlign')
l1=plt.plot(NAE2GT_clean_1 ,'b--',label='NoiseAug $\lambda=1.0$')
l1=plt.plot(NAE2GT_robustness_1 ,'b',label='NAE2GT_1.0')
l1=plt.plot(NAE2GT_clean_075 ,'y--',label='NAE2GT_0.75')
l1=plt.plot(NAE2GT_robustness_075 ,'y',label='NAE2GT_0.75')
l1=plt.plot(NAE2GT_clean_05 ,'g--',label='NAE2GT_0.5')
l1=plt.plot(NAE2GT_robustness_05 ,'g',label='NAE2GT_0.5')


plt.xlabel('Epoch',fontsize=20)
plt.ylabel('Accuracy',fontsize=20)

# fig.subplots_adjust(right=0.8)
# plt.tight_layout()
# plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0,fontsize=20)

plt.xlim((0, 30))
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

lgnd=plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0,numpoints=1,fontsize=14)
lgnd.legendHandles[0]._legmarker.set_markersize(16)
lgnd.legendHandles[1]._legmarker.set_markersize(10)
 
text = ax.text(-0.3,1, "", transform=ax.transAxes)

plt.savefig('KLandNAG2GT.pdf',bbox_extra_artists=(lgnd,text),bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35360/2388641727.py in <module>
#      12 l1=plt.plot(KL_reuslt_clean ,'r--',label='LogitAlign')
#      13 l1=plt.plot(KL_reuslt_robust ,'r',label='LogitAlign')
# ---> 14 l1=plt.plot(NAE2GT_clean_1 ,'b--',label='NoiseAug $\lambda=1.0$')
#      15 l1=plt.plot(NAE2GT_robustness_1 ,'b',label='NAE2GT_1.0')
#      16 l1=plt.plot(NAE2GT_clean_075 ,'y--',label='NAE2GT_0.75')
#
# NameError: name 'NAE2GT_clean_1' is not defined
